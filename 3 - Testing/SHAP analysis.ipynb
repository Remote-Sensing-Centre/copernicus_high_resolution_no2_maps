# %%
import joblib
import shap
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
OSM_ID = 8269826
MAP_HEX_SIZE = 7
DATASET_TYPE = "inference" # one of "training", "test" or "inference"
MODEL_COMMENT = "artificial_S5P_scaled" # String or None
DATA_COMMENT = "artificial_S5P_scaled_Gliwice" # String or None
SELECTED_YEARS = (2023, 2024)
years_str = "_".join(str(year) for year in SELECTED_YEARS)
if DATA_COMMENT:
    DATA_FILE = f"../data/NO2_{DATASET_TYPE}_dataset_osm_{OSM_ID}_hex_{MAP_HEX_SIZE}_year_{years_str}_{DATA_COMMENT}.csv"
else:
    DATA_FILE = f"../data/NO2_{DATASET_TYPE}_dataset_osm_{OSM_ID}_hex_{MAP_HEX_SIZE}_year_{years_str}.csv"
if MODEL_COMMENT:
    ML_MODEL = f"../data/random_forest_NO2_gios_{MODEL_COMMENT}.pkl"
else:
    ML_MODEL = f"../data/random_forest_NO2_gios.pkl"
SELECTED_PARAMETERS = [
    "tree_cover",
    "grassland",
    "population_density",
    "low_vegetation",
    "medium_vegetation",
    "high_vegetation",
    "road",
    "residential_1",
    "residential_2",
    "residential_3",
    "residential_4",
    "non-residential_1",
    "non-residential_2",
    "non-residential_3",
    "non-residential_4",
    "temperature",
    "temperature_trend_3h",
    "temperature_trend_6h",
    "temperature_anomaly",
    "relative_humidity",
    "relative_humidity_trend_3h",
    "relative_humidity_trend_6h",
    "pressure",
    "pressure_trend_3h",
    "pressure_trend_6h",
    "precipitation",
    "wind_speed",
    "traffic_mean_count",
    "day_of_year_sin",
    "day_of_year_cos",
    "working_day",
]
TARGET = "no2_gios"

# %%
mpl.rcParams["font.family"] = "Palatino Linotype"

# %%
df = pd.read_csv(DATA_FILE)
df = df[SELECTED_PARAMETERS]
df.dropna(inplace=True)
df.head()

# %%
rf_model = joblib.load(ML_MODEL)

# %%
features = list(df)
importances = rf_model.feature_importances_

df_importances = pd.DataFrame(index=features)
df_importances["importance"] = importances
df_importances.head()

# %%
X = df.sample(25000)

# %%
explainer = shap.TreeExplainer(rf_model, df.sample(1000))
shapley_values = explainer.shap_values(X, check_additivity=False)

# %%
df_importances["mean_shapley"] = np.mean(shapley_values, axis=0)
df_importances["mean_abs_shapley"] = np.mean(np.abs(shapley_values),axis=0)
df_importances.head()

# %%
df_importances.sort_values(by="importance", ascending=False).head(10).index

# %%
df_importances.sort_values(by="mean_abs_shapley", ascending=False).head(10).index

# %%
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111)
# Plot points
x = df_importances["importance"]
y = df_importances["mean_abs_shapley"]
ax.scatter(x, y)
ax.set_title("Shapley value vs model weight (coefficient) for each feature")
ax.set_ylabel("Mean absolute Shapley value")
ax.set_xlabel("Feature importance")
plt.grid()
plt.show()

# %%
mean_abs_shap = np.abs(shapley_values).mean(axis=0)
idx_sorted = np.argsort(mean_abs_shap)[::-1]

top_k = 18
top_idx = idx_sorted[:top_k]
rest_idx = idx_sorted[top_k:]

top_features = X.columns[top_idx]
remaining_features = X.columns[rest_idx]

# %%
shap.summary_plot(
    shap_values=shapley_values[:, top_idx],
    features=X.iloc[:, top_idx],
    feature_names=top_features,
    max_display=top_k,
    plot_size=(14, 10),
    show=False,
)

plt.tight_layout()

if DATA_COMMENT:
    top_file_name = f"shap_top_features_hex_{MAP_HEX_SIZE}_{DATA_COMMENT}.png"
else:
    top_file_name = f"shap_top_features_hex_{MAP_HEX_SIZE}.png"
plt.savefig(top_file_name, bbox_inches="tight")
plt.show()
plt.close()

# %%
shap.summary_plot(
    shap_values=shapley_values[:, rest_idx],
    features=X.iloc[:, rest_idx],
    feature_names=remaining_features,
    max_display=len(rest_idx),
    plot_size=(14, 10),
    show=False,
)

plt.tight_layout()

if DATA_COMMENT:
    remaining_file_name = f"shap_remaining_features_hex_{MAP_HEX_SIZE}_{DATA_COMMENT}.png"
else:
    remaining_file_name = f"shap_remaining_features_hex_{MAP_HEX_SIZE}.png"
plt.savefig(remaining_file_name, bbox_inches="tight")
plt.show()
plt.close()

# %% [markdown]
# ## Links
#
# [SHAP (SHapley Additive exPlanations)](https://github.com/shap/shap)
#
# [SHAP Values for Random Forest](https://medium.com/biased-algorithms/shap-values-for-random-forest-1150577563c9)
#
# [Explaining model predictions with Shapley values - Random Forest](https://michaelallen1966.github.io/titanic/27_random_forest_shap.html)
